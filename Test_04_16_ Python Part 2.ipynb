# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.Find the most expensive car company name

# %%
df=pd.read_csv(r'C:\Users\Laksh\Documents\Assignments\auto_temp.csv')

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized_losses         make fuel_type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#     aspiration num_doors   body_style drive_wheels engine_location  ...  \
# ...

# %%
highestprice = max(df['price'])
e
df['make'].value_counts()
toyota           32
nissan           18
mazda            17
mitsubishi       13
honda            13
volkswagen       12
subaru           12
peugot           11
volvo            11
dodge             9
mercedes-benz     8
bmw               8
audi              7
plymouth          7
saab              6
porsche           5
isuzu             4
jaguar            3
chevrolet         3
alfa-romero       3
renault           2
mercury           1
Name: make, dtype: int64
3. Find each company’s highest price car
ufacturers['make','price'].max()
priceDf
car_Manufacturers = df.groupby('make')
​
priceDf = car_Manufacturers['make','price'].max()
priceDf
C:\Users\Laksh\AppData\Local\Temp/ipykernel_16944/4177715369.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
  priceDf = car_Manufacturers['make','price'].max()
make	price
make		
alfa-romero	alfa-romero	16500.0
audi	audi	23875.0
bmw	bmw	41315.0
chevrolet	chevrolet	6575.0
dodge	dodge	12964.0
honda	honda	12945.0
isuzu	isuzu	11048.0
jaguar	jaguar	36000.0
mazda	mazda	18344.0
mercedes-benz	mercedes-benz	45400.0
mercury	mercury	16503.0
mitsubishi	mitsubishi	14869.0
nissan	nissan	19699.0
peugot	peugot	18150.0
plymouth	plymouth	12764.0
porsche	porsche	37028.0
renault	renault	9895.0
saab	saab	18620.0
subaru	subaru	11694.0
toyota	toyota	17669.0
volkswagen	volkswagen	13845.
highestprice
most_expensive_car = df[df['price'] == highestprice]['make'].to_string(index=False).strip()
most_expensive_car
# Out:
# 'mercedes-benz'

# %% [markdown]
# ### 2. Count total cars per company

# %%
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# ### 3. Find each company’s highest price car

# %%
priceDf = df.groupby('make')['price'].max()
priceDf
# Out:
# make
# alfa-romero      16500.0
# audi             23875.0
# bmw              41315.0
# chevrolet         6575.0
# dodge            12964.0
# honda            12945.0
# isuzu            11048.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mercury          16503.0
# mitsubishi       14869.0
# nissan           19699.0
# peugot           18150.0
# plymouth         12764.0
# porsche          37028.0
# renault           9895.0
# saab             18620.0
# subaru           11694.0
# toyota           17669.0
# volkswagen       13845.0
# volvo            22625.0
# Name: price, dtype: float64

# %% [markdown]
# ### 4.Sort all cars by Price column

# %%
priceDf.sort_values(ascending = False)
# Out:
# make
# mercedes-benz    45400.0
# bmw              41315.0
# porsche          37028.0
# jaguar           36000.0
# audi             23875.0
# volvo            22625.0
# nissan           19699.0
# saab             18620.0
# mazda            18344.0
# peugot           18150.0
# toyota           17669.0
# mercury          16503.0
# alfa-romero      16500.0
# mitsubishi       14869.0
# volkswagen       13845.0
# dodge            12964.0
# honda            12945.0
# plymouth         12764.0
# subaru           11694.0
# isuzu            11048.0
# renault           9895.0
# chevrolet         6575.0
# Name: price, dtype: float64

# %% [markdown]
# ### 5. Group by make, fuel-type and body-style to calculate the average of city-mpg and highway-mpg (miles per gallon)

# %%
print(df.groupby(['make','fuel_type','body_style']).agg({'city_mpg': ['mean'], 'highway_mpg' : ['mean']}))
# Out:
#                                     city_mpg highway_mpg
#                                         mean        mean
# make        fuel_type body_style
# alfa-romero gas       convertible  21.000000   27.000000
#                       hatchback    19.000000   26.000000
# audi        gas       hatchback    16.000000   22.000000
#                       sedan        19.400000   24.400000
#                       wagon        19.000000   25.000000
# ...                                      ...         ...
# volkswagen  gas       sedan        25.200000   31.600000
#                       wagon        25.000000   31.000000
# volvo       diesel    sedan        26.000000   27.000000
#             gas       sedan        20.428571   25.571429
#                       wagon        21.333333   26.000000
#
# [66 rows x 2 columns]
